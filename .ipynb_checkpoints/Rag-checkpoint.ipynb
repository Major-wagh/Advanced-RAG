# %%
import os
from tqdm import tqdm
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableLambda, RunnablePassthrough, RunnableParallel
from langchain_community.vectorstores import Milvus
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings = (
    OllamaEmbeddings(model="nomic-embed-text",base_url="http://localhost:11434")
)

# %%
loader = PyPDFDirectoryLoader("./pdfs-master")
docs = loader.load()
# Out:
# Ignoring wrong pointing object 19 0 (offset 0)
# Ignoring wrong pointing object 285 0 (offset 0)
# Ignoring wrong pointing object 287 0 (offset 0)
# Ignoring wrong pointing object 289 0 (offset 0)
# Ignoring wrong pointing object 291 0 (offset 0)
# Ignoring wrong pointing object 299 0 (offset 0)
# Ignoring wrong pointing object 301 0 (offset 0)
# Ignoring wrong pointing object 303 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 13 0 (offset 0)
# Ignoring wrong pointing object 273 0 (offset 0)
# Ignoring wrong pointing object 275 0 (offset 0)
# Ignoring wrong pointing object 278 0 (offset 0)
# Ignoring wrong pointing object 280 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 45 0 (offset 0)
# Ignoring wrong pointing object 198 0 (offset 0)
# Ignoring wrong pointing object 201 0 (offset 0)
# Ignoring wrong pointing object 203 0 (offset 0)
# Ignoring wrong pointing object 205 0 (offset 0)
# Ignoring wrong pointing object 237 0 (offset 0)
# Ignoring wrong pointing object 239 0 (offset 0)
# Ignoring wrong pointing object 242 0 (offset 0)
# Ignoring wrong pointing object 244 0 (offset 0)
# Ignoring wrong pointing object 434 0 (offset 0)
# Ignoring wrong pointing object 28 0 (offset 0)
# Ignoring wrong pointing object 52 0 (offset 0)
# Ignoring wrong pointing object 101 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 35 0 (offset 0)
# Ignoring wrong pointing object 205 0 (offset 0)
# Ignoring wrong pointing object 52 0 (offset 0)
# Ignoring wrong pointing object 73 0 (offset 0)
# Ignoring wrong pointing object 269 0 (offset 0)
# Ignoring wrong pointing object 9 0 (offset 0)
# Ignoring wrong pointing object 20 0 (offset 0)
# Ignoring wrong pointing object 107 0 (offset 0)
# Ignoring wrong pointing object 295 0 (offset 0)
# Ignoring wrong pointing object 627 0 (offset 0)
# Multiple definitions in dictionary at byte 0x4caf for key /ToUnicode
# Multiple definitions in dictionary at byte 0x4812 for key /ToUnicode
# Multiple definitions in dictionary at byte 0x497f for key /ToUnicode
# Multiple definitions in dictionary at byte 0x476f for key /ToUnicode
# Multiple definitions in dictionary at byte 0x48c8 for key /ToUnicode
# Multiple definitions in dictionary at byte 0x4629 for key /ToUnicode
# Multiple definitions in dictionary at byte 0x4a36 for key /ToUnicode
# Multiple definitions in dictionary at byte 0x46cc for key /ToUnicode
# Multiple definitions in dictionary at byte 0x4589 for key /ToUnicode
# Ignoring wrong pointing object 26 0 (offset 0)
# Ignoring wrong pointing object 37 0 (offset 0)
# Ignoring wrong pointing object 57 0 (offset 0)
# Ignoring wrong pointing object 137 0 (offset 0)
# Ignoring wrong pointing object 2 65536 (offset 0)
# Ignoring wrong pointing object 9 65536 (offset 0)
# Ignoring wrong pointing object 12 65536 (offset 0)
# Ignoring wrong pointing object 140 65536 (offset 0)
# Ignoring wrong pointing object 177 65536 (offset 0)
# Ignoring wrong pointing object 185 65536 (offset 0)
# Ignoring wrong pointing object 363 65536 (offset 0)
# Ignoring wrong pointing object 371 65536 (offset 0)
# Ignoring wrong pointing object 392 65536 (offset 0)
# Ignoring wrong pointing object 515 65536 (offset 0)
# Ignoring wrong pointing object 523 65536 (offset 0)
# Ignoring wrong pointing object 531 65536 (offset 0)
# Ignoring wrong pointing object 566 65536 (offset 0)
# Ignoring wrong pointing object 574 65536 (offset 0)
# Ignoring wrong pointing object 640 65536 (offset 0)
# Ignoring wrong pointing object 648 65536 (offset 0)
# Ignoring wrong pointing object 656 65536 (offset 0)
# Ignoring wrong pointing object 674 65536 (offset 0)
# Ignoring wrong pointing object 682 65536 (offset 0)
# Ignoring wrong pointing object 690 65536 (offset 0)
# Ignoring wrong pointing object 704 65536 (offset 0)
# Ignoring wrong pointing object 712 65536 (offset 0)
# Ignoring wrong pointing object 720 65536 (offset 0)
# Ignoring wrong pointing object 728 65536 (offset 0)
# Ignoring wrong pointing object 736 65536 (offset 0)
# Ignoring wrong pointing object 744 65536 (offset 0)
# Ignoring wrong pointing object 752 65536 (offset 0)
# Ignoring wrong pointing object 760 65536 (offset 0)
# Ignoring wrong pointing object 768 65536 (offset 0)
# Ignoring wrong pointing object 859 65536 (offset 0)
# Ignoring wrong pointing object 867 65536 (offset 0)
# Ignoring wrong pointing object 875 65536 (offset 0)
# Ignoring wrong pointing object 895 65536 (offset 0)
# Ignoring wrong pointing object 909 65536 (offset 0)
# Ignoring wrong pointing object 917 65536 (offset 0)
# Ignoring wrong pointing object 933 65536 (offset 0)
# Ignoring wrong pointing object 941 65536 (offset 0)
# Ignoring wrong pointing object 949 65536 (offset 0)
# Ignoring wrong pointing object 963 65536 (offset 0)
# Ignoring wrong pointing object 971 65536 (offset 0)
# Ignoring wrong pointing object 979 65536 (offset 0)
# Ignoring wrong pointing object 987 65536 (offset 0)
# Ignoring wrong pointing object 995 65536 (offset 0)
# Ignoring wrong pointing object 1003 65536 (offset 0)
# Ignoring wrong pointing object 1019 65536 (offset 0)
# Ignoring wrong pointing object 1032 65536 (offset 0)
# Ignoring wrong pointing object 1040 65536 (offset 0)
# Ignoring wrong pointing object 1048 65536 (offset 0)
# Ignoring wrong pointing object 1064 65536 (offset 0)
# Ignoring wrong pointing object 1075 65536 (offset 0)
# Ignoring wrong pointing object 1083 65536 (offset 0)
# Ignoring wrong pointing object 1094 65536 (offset 0)
# Ignoring wrong pointing object 1102 65536 (offset 0)
# Ignoring wrong pointing object 1110 65536 (offset 0)
# Ignoring wrong pointing object 1121 65536 (offset 0)
# Ignoring wrong pointing object 1129 65536 (offset 0)
# Ignoring wrong pointing object 1137 65536 (offset 0)
# Ignoring wrong pointing object 1148 65536 (offset 0)
# Ignoring wrong pointing object 1156 65536 (offset 0)
# Ignoring wrong pointing object 1164 65536 (offset 0)
# Ignoring wrong pointing object 1172 65536 (offset 0)
# Ignoring wrong pointing object 1180 65536 (offset 0)
# Ignoring wrong pointing object 1188 65536 (offset 0)
# Ignoring wrong pointing object 1196 65536 (offset 0)
# Ignoring wrong pointing object 1204 65536 (offset 0)
# Ignoring wrong pointing object 1212 65536 (offset 0)
# Ignoring wrong pointing object 1220 65536 (offset 0)
# Ignoring wrong pointing object 1228 65536 (offset 0)
# Ignoring wrong pointing object 1236 65536 (offset 0)
# Ignoring wrong pointing object 1244 65536 (offset 0)
# Ignoring wrong pointing object 1252 65536 (offset 0)
# Ignoring wrong pointing object 1271 65536 (offset 0)
# Ignoring wrong pointing object 1279 65536 (offset 0)
# Ignoring wrong pointing object 1287 65536 (offset 0)
# Ignoring wrong pointing object 1305 65536 (offset 0)
# Ignoring wrong pointing object 1313 65536 (offset 0)
# Ignoring wrong pointing object 1340 65536 (offset 0)
# Ignoring wrong pointing object 1358 65536 (offset 0)
# Ignoring wrong pointing object 1366 65536 (offset 0)
# Ignoring wrong pointing object 1374 65536 (offset 0)
# Ignoring wrong pointing object 1382 65536 (offset 0)
# Ignoring wrong pointing object 1390 65536 (offset 0)
# Ignoring wrong pointing object 1398 65536 (offset 0)
# Ignoring wrong pointing object 1428 65536 (offset 0)
# Ignoring wrong pointing object 1439 65536 (offset 0)
# Ignoring wrong pointing object 1447 65536 (offset 0)
# Ignoring wrong pointing object 1455 65536 (offset 0)
# Ignoring wrong pointing object 1463 65536 (offset 0)
# Ignoring wrong pointing object 1481 65536 (offset 0)
# Ignoring wrong pointing object 1508 65536 (offset 0)
# Ignoring wrong pointing object 1516 65536 (offset 0)
# Ignoring wrong pointing object 1524 65536 (offset 0)
# Ignoring wrong pointing object 1551 65536 (offset 0)
# Ignoring wrong pointing object 1564 65536 (offset 0)
# Ignoring wrong pointing object 1578 65536 (offset 0)
# Ignoring wrong pointing object 1586 65536 (offset 0)
# Ignoring wrong pointing object 1621 65536 (offset 0)
# Ignoring wrong pointing object 1648 65536 (offset 0)
# Ignoring wrong pointing object 1656 65536 (offset 0)
# Ignoring wrong pointing object 1664 65536 (offset 0)
# Ignoring wrong pointing object 1691 65536 (offset 0)
# Ignoring wrong pointing object 1708 65536 (offset 0)
# Ignoring wrong pointing object 1716 65536 (offset 0)
# Ignoring wrong pointing object 1724 65536 (offset 0)
# Ignoring wrong pointing object 1732 65536 (offset 0)
# Ignoring wrong pointing object 1740 65536 (offset 0)
# Ignoring wrong pointing object 1748 65536 (offset 0)
# Ignoring wrong pointing object 1756 65536 (offset 0)
# Ignoring wrong pointing object 1764 65536 (offset 0)
# Ignoring wrong pointing object 1772 65536 (offset 0)
# Ignoring wrong pointing object 1799 65536 (offset 0)
# Ignoring wrong pointing object 1824 65536 (offset 0)
# Ignoring wrong pointing object 1832 65536 (offset 0)
# Ignoring wrong pointing object 1850 65536 (offset 0)
# Ignoring wrong pointing object 1867 65536 (offset 0)
# Ignoring wrong pointing object 1875 65536 (offset 0)
# Ignoring wrong pointing object 3176 65536 (offset 0)
# Ignoring wrong pointing object 3446 65536 (offset 0)
# Ignoring wrong pointing object 3463 65536 (offset 0)
# Ignoring wrong pointing object 3471 65536 (offset 0)
# Ignoring wrong pointing object 3533 65536 (offset 0)
# Ignoring wrong pointing object 3541 65536 (offset 0)
# Ignoring wrong pointing object 3549 65536 (offset 0)
# Ignoring wrong pointing object 3557 65536 (offset 0)
# Ignoring wrong pointing object 3565 65536 (offset 0)
# Ignoring wrong pointing object 3573 65536 (offset 0)
# Ignoring wrong pointing object 3581 65536 (offset 0)
# Ignoring wrong pointing object 3589 65536 (offset 0)
# Ignoring wrong pointing object 3597 65536 (offset 0)
# Ignoring wrong pointing object 3605 65536 (offset 0)
# Ignoring wrong pointing object 3613 65536 (offset 0)
# Ignoring wrong pointing object 3621 65536 (offset 0)
# Ignoring wrong pointing object 3629 65536 (offset 0)
# Ignoring wrong pointing object 3637 65536 (offset 0)
# Ignoring wrong pointing object 3645 65536 (offset 0)
# Ignoring wrong pointing object 3653 65536 (offset 0)
# Ignoring wrong pointing object 3661 65536 (offset 0)
# Ignoring wrong pointing object 3669 65536 (offset 0)
# Ignoring wrong pointing object 3677 65536 (offset 0)
# Ignoring wrong pointing object 3685 65536 (offset 0)
# Ignoring wrong pointing object 3693 65536 (offset 0)
# Ignoring wrong pointing object 3701 65536 (offset 0)
# Ignoring wrong pointing object 3709 65536 (offset 0)
# Ignoring wrong pointing object 3717 65536 (offset 0)
# Ignoring wrong pointing object 3725 65536 (offset 0)
# Ignoring wrong pointing object 3733 65536 (offset 0)
# Ignoring wrong pointing object 3751 65536 (offset 0)
# Ignoring wrong pointing object 3759 65536 (offset 0)
# Ignoring wrong pointing object 3767 65536 (offset 0)
# Ignoring wrong pointing object 3775 65536 (offset 0)
# Ignoring wrong pointing object 3783 65536 (offset 0)
# Ignoring wrong pointing object 3791 65536 (offset 0)
# Ignoring wrong pointing object 3799 65536 (offset 0)
# Ignoring wrong pointing object 3807 65536 (offset 0)
# Ignoring wrong pointing object 3815 65536 (offset 0)
# Ignoring wrong pointing object 3826 65536 (offset 0)
# Ignoring wrong pointing object 3834 65536 (offset 0)
# Ignoring wrong pointing object 3842 65536 (offset 0)
# Ignoring wrong pointing object 3850 65536 (offset 0)
# Ignoring wrong pointing object 3858 65536 (offset 0)
# Ignoring wrong pointing object 3866 65536 (offset 0)
# Ignoring wrong pointing object 3874 65536 (offset 0)
# Ignoring wrong pointing object 3882 65536 (offset 0)
# Ignoring wrong pointing object 3890 65536 (offset 0)
# Ignoring wrong pointing object 3898 65536 (offset 0)
# Ignoring wrong pointing object 3925 65536 (offset 0)
# Ignoring wrong pointing object 3933 65536 (offset 0)
# Ignoring wrong pointing object 3941 65536 (offset 0)
# Ignoring wrong pointing object 3949 65536 (offset 0)
# Ignoring wrong pointing object 3957 65536 (offset 0)
# Ignoring wrong pointing object 3965 65536 (offset 0)
# Ignoring wrong pointing object 3973 65536 (offset 0)
# Ignoring wrong pointing object 4005 65536 (offset 0)
# Ignoring wrong pointing object 4013 65536 (offset 0)
# Ignoring wrong pointing object 4021 65536 (offset 0)
# Ignoring wrong pointing object 4029 65536 (offset 0)
# Ignoring wrong pointing object 4037 65536 (offset 0)
# Ignoring wrong pointing object 4045 65536 (offset 0)
# Ignoring wrong pointing object 4053 65536 (offset 0)
# Ignoring wrong pointing object 4061 65536 (offset 0)
# Ignoring wrong pointing object 4069 65536 (offset 0)
# Ignoring wrong pointing object 4077 65536 (offset 0)
# Ignoring wrong pointing object 4085 65536 (offset 0)
# Ignoring wrong pointing object 4093 65536 (offset 0)
# Ignoring wrong pointing object 4101 65536 (offset 0)
# Ignoring wrong pointing object 4109 65536 (offset 0)
# Ignoring wrong pointing object 4117 65536 (offset 0)
# Ignoring wrong pointing object 4125 65536 (offset 0)
# Ignoring wrong pointing object 4133 65536 (offset 0)
# Ignoring wrong pointing object 4141 65536 (offset 0)
# Ignoring wrong pointing object 4149 65536 (offset 0)
# Ignoring wrong pointing object 4157 65536 (offset 0)
# Ignoring wrong pointing object 4165 65536 (offset 0)
# Ignoring wrong pointing object 4173 65536 (offset 0)
# Ignoring wrong pointing object 4181 65536 (offset 0)
# Ignoring wrong pointing object 4189 65536 (offset 0)
# Ignoring wrong pointing object 4197 65536 (offset 0)
# Ignoring wrong pointing object 4205 65536 (offset 0)
# Ignoring wrong pointing object 4231 65536 (offset 0)
# Ignoring wrong pointing object 4239 65536 (offset 0)
# Ignoring wrong pointing object 4247 65536 (offset 0)
# Ignoring wrong pointing object 4255 65536 (offset 0)
# Ignoring wrong pointing object 4263 65536 (offset 0)
# Ignoring wrong pointing object 4271 65536 (offset 0)
# Ignoring wrong pointing object 4279 65536 (offset 0)
# Ignoring wrong pointing object 4287 65536 (offset 0)
# Ignoring wrong pointing object 4295 65536 (offset 0)
# Ignoring wrong pointing object 4303 65536 (offset 0)
# Ignoring wrong pointing object 4311 65536 (offset 0)
# Ignoring wrong pointing object 4319 65536 (offset 0)
# Ignoring wrong pointing object 4327 65536 (offset 0)
# Ignoring wrong pointing object 4335 65536 (offset 0)
# Ignoring wrong pointing object 4343 65536 (offset 0)
# Ignoring wrong pointing object 4351 65536 (offset 0)
# Ignoring wrong pointing object 4359 65536 (offset 0)
# Ignoring wrong pointing object 4367 65536 (offset 0)
# Ignoring wrong pointing object 9 0 (offset 0)
# Ignoring wrong pointing object 20 0 (offset 0)
# Ignoring wrong pointing object 30 0 (offset 0)
# Ignoring wrong pointing object 95 0 (offset 0)
# Ignoring wrong pointing object 97 0 (offset 0)
# Ignoring wrong pointing object 161 0 (offset 0)
# Ignoring wrong pointing object 163 0 (offset 0)
# Ignoring wrong pointing object 198 0 (offset 0)
# Ignoring wrong pointing object 213 0 (offset 0)
# Ignoring wrong pointing object 215 0 (offset 0)
# Ignoring wrong pointing object 219 0 (offset 0)
# Ignoring wrong pointing object 1384 0 (offset 0)
# Ignoring wrong pointing object 1487 0 (offset 0)
# Ignoring wrong pointing object 2758 0 (offset 0)
# Ignoring wrong pointing object 2760 0 (offset 0)
# Ignoring wrong pointing object 2764 0 (offset 0)
# Ignoring wrong pointing object 2790 0 (offset 0)
# Ignoring wrong pointing object 2809 0 (offset 0)
# invalid pdf header: b'/pdfh'
# incorrect startxref pointer(1)
# invalid pdf header: b'#%PDF'
# Ignoring wrong pointing object 11 0 (offset 0)
# Ignoring wrong pointing object 25 0 (offset 0)
# Multiple definitions in dictionary at byte 0x2671 for key /ToUnicode
# Multiple definitions in dictionary at byte 0x25ac for key /ToUnicode
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 666 0 (offset 0)
# Ignoring wrong pointing object 692 0 (offset 0)
# Ignoring wrong pointing object 707 0 (offset 0)
# Ignoring wrong pointing object 1083 0 (offset 0)
# Ignoring wrong pointing object 11 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 25 0 (offset 0)
# Ignoring wrong pointing object 108 0 (offset 0)
# Ignoring wrong pointing object 2 0 (offset 0)
# Ignoring wrong pointing object 81 0 (offset 0)
# Ignoring wrong pointing object 114 0 (offset 0)
# Ignoring wrong pointing object 162 0 (offset 0)
# Ignoring wrong pointing object 219 0 (offset 0)
# Ignoring wrong pointing object 243 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 0 0 (offset 0)
# Ignoring wrong pointing object 115 0 (offset 0)
# Ignoring wrong pointing object 116 0 (offset 0)
# Ignoring wrong pointing object 161 0 (offset 0)
# Ignoring wrong pointing object 1 65536 (offset 0)
# Ignoring wrong pointing object 9 65536 (offset 0)
# Ignoring wrong pointing object 12 65536 (offset 0)
# Ignoring wrong pointing object 24 65536 (offset 0)
# Ignoring wrong pointing object 36 65536 (offset 0)
# Ignoring wrong pointing object 48 65536 (offset 0)
# Ignoring wrong pointing object 88 65536 (offset 0)
# Ignoring wrong pointing object 140 65536 (offset 0)
# Ignoring wrong pointing object 200 65536 (offset 0)
# Ignoring wrong pointing object 241 65536 (offset 0)
# Ignoring wrong pointing object 278 65536 (offset 0)
# Ignoring wrong pointing object 326 65536 (offset 0)
# Ignoring wrong pointing object 341 65536 (offset 0)
# Ignoring wrong pointing object 345 65536 (offset 0)
# Ignoring wrong pointing object 349 65536 (offset 0)
# Ignoring wrong pointing object 361 65536 (offset 0)
# Ignoring wrong pointing object 384 65536 (offset 0)
# Ignoring wrong pointing object 400 65536 (offset 0)
# Ignoring wrong pointing object 414 65536 (offset 0)
# Ignoring wrong pointing object 425 65536 (offset 0)
# Ignoring wrong pointing object 443 65536 (offset 0)
# Ignoring wrong pointing object 449 65536 (offset 0)
# Ignoring wrong pointing object 465 65536 (offset 0)
# Ignoring wrong pointing object 473 65536 (offset 0)
# Ignoring wrong pointing object 483 65536 (offset 0)
# Ignoring wrong pointing object 497 65536 (offset 0)
# Ignoring wrong pointing object 500 65536 (offset 0)
# Ignoring wrong pointing object 505 65536 (offset 0)
# Ignoring wrong pointing object 511 65536 (offset 0)
# Ignoring wrong pointing object 515 65536 (offset 0)
# Ignoring wrong pointing object 524 65536 (offset 0)
# Ignoring wrong pointing object 528 65536 (offset 0)
# Ignoring wrong pointing object 532 65536 (offset 0)
# Ignoring wrong pointing object 540 65536 (offset 0)
# Ignoring wrong pointing object 549 65536 (offset 0)
# Ignoring wrong pointing object 555 65536 (offset 0)
# Ignoring wrong pointing object 560 65536 (offset 0)
# Ignoring wrong pointing object 569 65536 (offset 0)
# Ignoring wrong pointing object 576 65536 (offset 0)
# Ignoring wrong pointing object 584 65536 (offset 0)
# Ignoring wrong pointing object 597 65536 (offset 0)
# Ignoring wrong pointing object 615 65536 (offset 0)
# Ignoring wrong pointing object 621 65536 (offset 0)
# Ignoring wrong pointing object 641 65536 (offset 0)
# Ignoring wrong pointing object 647 65536 (offset 0)
# Ignoring wrong pointing object 652 65536 (offset 0)
# Ignoring wrong pointing object 663 65536 (offset 0)
# Ignoring wrong pointing object 678 65536 (offset 0)
# Ignoring wrong pointing object 690 65536 (offset 0)
# Ignoring wrong pointing object 701 65536 (offset 0)
# Ignoring wrong pointing object 706 65536 (offset 0)
# Ignoring wrong pointing object 712 65536 (offset 0)
# Ignoring wrong pointing object 721 65536 (offset 0)
# Ignoring wrong pointing object 725 65536 (offset 0)
# Ignoring wrong pointing object 729 65536 (offset 0)
# Ignoring wrong pointing object 734 65536 (offset 0)
# Ignoring wrong pointing object 739 65536 (offset 0)
# Ignoring wrong pointing object 745 65536 (offset 0)
# Ignoring wrong pointing object 750 65536 (offset 0)
# Ignoring wrong pointing object 759 65536 (offset 0)
# Ignoring wrong pointing object 767 65536 (offset 0)
# Ignoring wrong pointing object 774 65536 (offset 0)
# Ignoring wrong pointing object 788 65536 (offset 0)
# Ignoring wrong pointing object 795 65536 (offset 0)
# Ignoring wrong pointing object 805 65536 (offset 0)
# Ignoring wrong pointing object 811 65536 (offset 0)
# Ignoring wrong pointing object 821 65536 (offset 0)
# Ignoring wrong pointing object 829 65536 (offset 0)
# Ignoring wrong pointing object 837 65536 (offset 0)
# Ignoring wrong pointing object 841 65536 (offset 0)
# Ignoring wrong pointing object 850 65536 (offset 0)
# Ignoring wrong pointing object 859 65536 (offset 0)
# Ignoring wrong pointing object 863 65536 (offset 0)
# Ignoring wrong pointing object 866 65536 (offset 0)
# Ignoring wrong pointing object 872 65536 (offset 0)
# Ignoring wrong pointing object 877 65536 (offset 0)
# Ignoring wrong pointing object 882 65536 (offset 0)
# Ignoring wrong pointing object 891 65536 (offset 0)
# Ignoring wrong pointing object 895 65536 (offset 0)
# Ignoring wrong pointing object 899 65536 (offset 0)
# Ignoring wrong pointing object 904 65536 (offset 0)
# Ignoring wrong pointing object 909 65536 (offset 0)
# Ignoring wrong pointing object 915 65536 (offset 0)
# Ignoring wrong pointing object 934 65536 (offset 0)
# Ignoring wrong pointing object 954 65536 (offset 0)
# Ignoring wrong pointing object 960 65536 (offset 0)
# Ignoring wrong pointing object 989 65536 (offset 0)
# Ignoring wrong pointing object 1002 65536 (offset 0)
# Ignoring wrong pointing object 1030 65536 (offset 0)
# Ignoring wrong pointing object 1033 65536 (offset 0)
# Ignoring wrong pointing object 1038 65536 (offset 0)
# Ignoring wrong pointing object 1044 65536 (offset 0)
# Ignoring wrong pointing object 1054 65536 (offset 0)
# Ignoring wrong pointing object 1059 65536 (offset 0)
# Ignoring wrong pointing object 1064 65536 (offset 0)
# Ignoring wrong pointing object 1068 65536 (offset 0)
# Ignoring wrong pointing object 1077 65536 (offset 0)
# Ignoring wrong pointing object 1085 65536 (offset 0)
# Ignoring wrong pointing object 1089 65536 (offset 0)
# Ignoring wrong pointing object 1096 65536 (offset 0)
# Ignoring wrong pointing object 1101 65536 (offset 0)
# Ignoring wrong pointing object 1114 65536 (offset 0)
# Ignoring wrong pointing object 1120 65536 (offset 0)
# Ignoring wrong pointing object 1128 65536 (offset 0)
# Ignoring wrong pointing object 1133 65536 (offset 0)
# Ignoring wrong pointing object 1142 65536 (offset 0)
# Ignoring wrong pointing object 1145 65536 (offset 0)
# Ignoring wrong pointing object 1148 65536 (offset 0)
# Ignoring wrong pointing object 1156 65536 (offset 0)
# Ignoring wrong pointing object 1162 65536 (offset 0)
# Ignoring wrong pointing object 1171 65536 (offset 0)
# Ignoring wrong pointing object 1178 65536 (offset 0)
# Ignoring wrong pointing object 1183 65536 (offset 0)
# Ignoring wrong pointing object 1188 65536 (offset 0)
# Ignoring wrong pointing object 1201 65536 (offset 0)
# Ignoring wrong pointing object 1215 65536 (offset 0)
# Ignoring wrong pointing object 1229 65536 (offset 0)
# Ignoring wrong pointing object 1232 65536 (offset 0)
# Ignoring wrong pointing object 1245 65536 (offset 0)
# Ignoring wrong pointing object 1259 65536 (offset 0)
# Ignoring wrong pointing object 1267 65536 (offset 0)
# Ignoring wrong pointing object 1277 65536 (offset 0)
# Ignoring wrong pointing object 1282 65536 (offset 0)
# Ignoring wrong pointing object 1287 65536 (offset 0)
# Ignoring wrong pointing object 1290 65536 (offset 0)
# Ignoring wrong pointing object 1294 65536 (offset 0)
# Ignoring wrong pointing object 1308 65536 (offset 0)
# Ignoring wrong pointing object 1315 65536 (offset 0)
# Ignoring wrong pointing object 1338 65536 (offset 0)
# Ignoring wrong pointing object 1359 65536 (offset 0)
# Ignoring wrong pointing object 1366 65536 (offset 0)
# Ignoring wrong pointing object 1375 65536 (offset 0)
# Ignoring wrong pointing object 1380 65536 (offset 0)
# Ignoring wrong pointing object 1385 65536 (offset 0)
# Ignoring wrong pointing object 1393 65536 (offset 0)
# Ignoring wrong pointing object 1428 65536 (offset 0)
# Ignoring wrong pointing object 1438 65536 (offset 0)
# Ignoring wrong pointing object 1463 65536 (offset 0)
# Ignoring wrong pointing object 1472 65536 (offset 0)
# Ignoring wrong pointing object 1478 65536 (offset 0)
# Ignoring wrong pointing object 1497 65536 (offset 0)
# Ignoring wrong pointing object 1511 65536 (offset 0)
# Ignoring wrong pointing object 1516 65536 (offset 0)
# Ignoring wrong pointing object 1532 65536 (offset 0)
# Ignoring wrong pointing object 1586 65536 (offset 0)
# Ignoring wrong pointing object 1593 65536 (offset 0)
# Ignoring wrong pointing object 1597 65536 (offset 0)
# Ignoring wrong pointing object 1609 65536 (offset 0)
# Ignoring wrong pointing object 1613 65536 (offset 0)
# Ignoring wrong pointing object 1616 65536 (offset 0)
# Ignoring wrong pointing object 1627 65536 (offset 0)
# Ignoring wrong pointing object 1632 65536 (offset 0)
# Ignoring wrong pointing object 1641 65536 (offset 0)
# Ignoring wrong pointing object 1645 65536 (offset 0)
# Ignoring wrong pointing object 1651 65536 (offset 0)
# Ignoring wrong pointing object 1658 65536 (offset 0)
# Ignoring wrong pointing object 1662 65536 (offset 0)
# Ignoring wrong pointing object 1667 65536 (offset 0)
# Ignoring wrong pointing object 1671 65536 (offset 0)
# Ignoring wrong pointing object 1676 65536 (offset 0)
# Ignoring wrong pointing object 1680 65536 (offset 0)
# Ignoring wrong pointing object 1686 65536 (offset 0)
# Ignoring wrong pointing object 1693 65536 (offset 0)
# Ignoring wrong pointing object 1702 65536 (offset 0)
# Ignoring wrong pointing object 1709 65536 (offset 0)
# Ignoring wrong pointing object 1712 65536 (offset 0)
# Ignoring wrong pointing object 1718 65536 (offset 0)
# Ignoring wrong pointing object 1721 65536 (offset 0)
# Ignoring wrong pointing object 1724 65536 (offset 0)
# Ignoring wrong pointing object 1727 65536 (offset 0)
# Ignoring wrong pointing object 1730 65536 (offset 0)
# Ignoring wrong pointing object 1734 65536 (offset 0)
# Ignoring wrong pointing object 1737 65536 (offset 0)
# Ignoring wrong pointing object 1740 65536 (offset 0)
# Ignoring wrong pointing object 1743 65536 (offset 0)
# Ignoring wrong pointing object 1746 65536 (offset 0)
# Ignoring wrong pointing object 32 0 (offset 0)
# Ignoring wrong pointing object 34 0 (offset 0)
# Ignoring wrong pointing object 375 0 (offset 0)
# Ignoring wrong pointing object 86 0 (offset 0)
# Ignoring wrong pointing object 88 0 (offset 0)
# Ignoring wrong pointing object 90 0 (offset 0)
# Ignoring wrong pointing object 111 0 (offset 0)
# Ignoring wrong pointing object 114 0 (offset 0)
# Ignoring wrong pointing object 132 0 (offset 0)
# Ignoring wrong pointing object 134 0 (offset 0)
# Ignoring wrong pointing object 195 0 (offset 0)
# Ignoring wrong pointing object 225 0 (offset 0)
# Ignoring wrong pointing object 252 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 36 0 (offset 0)
# Ignoring wrong pointing object 39 0 (offset 0)
# Ignoring wrong pointing object 76 0 (offset 0)
# Ignoring wrong pointing object 127 0 (offset 0)
# Ignoring wrong pointing object 141 0 (offset 0)
# Ignoring wrong pointing object 217 0 (offset 0)
# Ignoring wrong pointing object 219 0 (offset 0)
# Ignoring wrong pointing object 226 0 (offset 0)
# Ignoring wrong pointing object 285 0 (offset 0)
# Ignoring wrong pointing object 287 0 (offset 0)
# Ignoring wrong pointing object 356 0 (offset 0)
# Ignoring wrong pointing object 411 0 (offset 0)
# Ignoring wrong pointing object 639 0 (offset 0)
# Ignoring wrong pointing object 820 0 (offset 0)
# Ignoring wrong pointing object 902 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 60 0 (offset 0)
#  impossible to decode XFormObject /Pol6
#  impossible to decode XFormObject /Pol14
#  impossible to decode XFormObject /Pol21
#  impossible to decode XFormObject /Pol28
#  impossible to decode XFormObject /Pol35
#  impossible to decode XFormObject /Pol54
#  impossible to decode XFormObject /Pol61
#  impossible to decode XFormObject /Pol68
#  impossible to decode XFormObject /Pol75
#  impossible to decode XFormObject /Pol82
#  impossible to decode XFormObject /Pol89
#  impossible to decode XFormObject /Pol96
#  impossible to decode XFormObject /Pol107
#  impossible to decode XFormObject /Pol114
#  impossible to decode XFormObject /Pol121
#  impossible to decode XFormObject /Pol128
#  impossible to decode XFormObject /Pol135
#  impossible to decode XFormObject /Pol142
#  impossible to decode XFormObject /Pol153
#  impossible to decode XFormObject /Pol160
#  impossible to decode XFormObject /Pol167
#  impossible to decode XFormObject /Pol174
#  impossible to decode XFormObject /Pol181
# Ignoring wrong pointing object 2 65536 (offset 0)
# Ignoring wrong pointing object 30 65536 (offset 0)
# Ignoring wrong pointing object 60 65536 (offset 0)
# Ignoring wrong pointing object 69 65536 (offset 0)
# Ignoring wrong pointing object 114 65536 (offset 0)
# Ignoring wrong pointing object 118 65536 (offset 0)
# Ignoring wrong pointing object 122 65536 (offset 0)
# Ignoring wrong pointing object 136 65536 (offset 0)
# Ignoring wrong pointing object 147 65536 (offset 0)
# Ignoring wrong pointing object 175 65536 (offset 0)
# Ignoring wrong pointing object 183 65536 (offset 0)
# Ignoring wrong pointing object 202 65536 (offset 0)
# Ignoring wrong pointing object 221 65536 (offset 0)
# Ignoring wrong pointing object 229 65536 (offset 0)
# Ignoring wrong pointing object 237 65536 (offset 0)
# Ignoring wrong pointing object 245 65536 (offset 0)
# Ignoring wrong pointing object 249 65536 (offset 0)
# Ignoring wrong pointing object 253 65536 (offset 0)
# Ignoring wrong pointing object 281 65536 (offset 0)
# Ignoring wrong pointing object 297 65536 (offset 0)
# Ignoring wrong pointing object 330 65536 (offset 0)
# Ignoring wrong pointing object 337 65536 (offset 0)
# Ignoring wrong pointing object 341 65536 (offset 0)
# Ignoring wrong pointing object 349 65536 (offset 0)
# Ignoring wrong pointing object 360 65536 (offset 0)
# Ignoring wrong pointing object 391 65536 (offset 0)
# Ignoring wrong pointing object 396 65536 (offset 0)
# Ignoring wrong pointing object 432 65536 (offset 0)
# Ignoring wrong pointing object 487 65536 (offset 0)
# Ignoring wrong pointing object 491 65536 (offset 0)
# Ignoring wrong pointing object 501 65536 (offset 0)
# Ignoring wrong pointing object 505 65536 (offset 0)
# Ignoring wrong pointing object 509 65536 (offset 0)
# Ignoring wrong pointing object 541 65536 (offset 0)
# Ignoring wrong pointing object 545 65536 (offset 0)
# Ignoring wrong pointing object 555 65536 (offset 0)
# Ignoring wrong pointing object 596 65536 (offset 0)
# Ignoring wrong pointing object 603 65536 (offset 0)
# Ignoring wrong pointing object 613 65536 (offset 0)
# Ignoring wrong pointing object 620 65536 (offset 0)
# Ignoring wrong pointing object 626 65536 (offset 0)
# Ignoring wrong pointing object 632 65536 (offset 0)
# Ignoring wrong pointing object 655 65536 (offset 0)
# Ignoring wrong pointing object 659 65536 (offset 0)
# Ignoring wrong pointing object 663 65536 (offset 0)
# Ignoring wrong pointing object 691 65536 (offset 0)
# Ignoring wrong pointing object 721 65536 (offset 0)
# Ignoring wrong pointing object 730 65536 (offset 0)
# Ignoring wrong pointing object 775 65536 (offset 0)
# Ignoring wrong pointing object 779 65536 (offset 0)
# Ignoring wrong pointing object 783 65536 (offset 0)
# Ignoring wrong pointing object 797 65536 (offset 0)
# Ignoring wrong pointing object 820 65536 (offset 0)
# Ignoring wrong pointing object 835 65536 (offset 0)
# Ignoring wrong pointing object 884 65536 (offset 0)
# Ignoring wrong pointing object 1067 65536 (offset 0)
# Ignoring wrong pointing object 1071 65536 (offset 0)
# Ignoring wrong pointing object 1076 65536 (offset 0)
# Ignoring wrong pointing object 1084 65536 (offset 0)
# Ignoring wrong pointing object 1088 65536 (offset 0)
# Ignoring wrong pointing object 1092 65536 (offset 0)
# Ignoring wrong pointing object 1096 65536 (offset 0)
# Ignoring wrong pointing object 1100 65536 (offset 0)
# Ignoring wrong pointing object 1104 65536 (offset 0)
# Ignoring wrong pointing object 1108 65536 (offset 0)
# Ignoring wrong pointing object 1112 65536 (offset 0)
# Ignoring wrong pointing object 1116 65536 (offset 0)
# Ignoring wrong pointing object 1120 65536 (offset 0)
# Ignoring wrong pointing object 1127 65536 (offset 0)
# Ignoring wrong pointing object 1131 65536 (offset 0)
# Ignoring wrong pointing object 1143 65536 (offset 0)
# Ignoring wrong pointing object 1151 65536 (offset 0)
# Ignoring wrong pointing object 1161 65536 (offset 0)
# Ignoring wrong pointing object 1176 65536 (offset 0)
# Ignoring wrong pointing object 1182 65536 (offset 0)
# Ignoring wrong pointing object 1188 65536 (offset 0)
# Ignoring wrong pointing object 1194 65536 (offset 0)
# Ignoring wrong pointing object 1205 65536 (offset 0)
# Ignoring wrong pointing object 1209 65536 (offset 0)
# Ignoring wrong pointing object 1217 65536 (offset 0)
# Ignoring wrong pointing object 1221 65536 (offset 0)
# Ignoring wrong pointing object 1230 65536 (offset 0)
# Ignoring wrong pointing object 1234 65536 (offset 0)
# Ignoring wrong pointing object 1240 65536 (offset 0)
# Ignoring wrong pointing object 1244 65536 (offset 0)
# Ignoring wrong pointing object 1280 65536 (offset 0)
# Ignoring wrong pointing object 1298 65536 (offset 0)
# Ignoring wrong pointing object 1311 65536 (offset 0)
# Ignoring wrong pointing object 1327 65536 (offset 0)
# Ignoring wrong pointing object 1340 65536 (offset 0)
# Ignoring wrong pointing object 1344 65536 (offset 0)
# Ignoring wrong pointing object 1349 65536 (offset 0)
# Ignoring wrong pointing object 1354 65536 (offset 0)
# Ignoring wrong pointing object 1358 65536 (offset 0)
# Ignoring wrong pointing object 1366 65536 (offset 0)
# Ignoring wrong pointing object 1394 65536 (offset 0)
# Ignoring wrong pointing object 1411 65536 (offset 0)
# Ignoring wrong pointing object 1425 65536 (offset 0)
# Ignoring wrong pointing object 1451 65536 (offset 0)
# Ignoring wrong pointing object 1468 65536 (offset 0)
# Ignoring wrong pointing object 1479 65536 (offset 0)
# Ignoring wrong pointing object 1486 65536 (offset 0)
# Ignoring wrong pointing object 1496 65536 (offset 0)
# Ignoring wrong pointing object 1503 65536 (offset 0)
# Ignoring wrong pointing object 1510 65536 (offset 0)
# Ignoring wrong pointing object 1517 65536 (offset 0)
# Ignoring wrong pointing object 1521 65536 (offset 0)
# Ignoring wrong pointing object 1529 65536 (offset 0)
# Ignoring wrong pointing object 1538 65536 (offset 0)
# Ignoring wrong pointing object 1542 65536 (offset 0)
# Ignoring wrong pointing object 1546 65536 (offset 0)
# Ignoring wrong pointing object 1550 65536 (offset 0)
# Ignoring wrong pointing object 1578 65536 (offset 0)
# Ignoring wrong pointing object 1596 65536 (offset 0)
# Ignoring wrong pointing object 1626 65536 (offset 0)
# Ignoring wrong pointing object 1635 65536 (offset 0)
# Ignoring wrong pointing object 1641 65536 (offset 0)
# Ignoring wrong pointing object 1651 65536 (offset 0)
# Ignoring wrong pointing object 1664 65536 (offset 0)
# Ignoring wrong pointing object 1674 65536 (offset 0)
# Ignoring wrong pointing object 1697 65536 (offset 0)
# Ignoring wrong pointing object 1743 65536 (offset 0)
# Ignoring wrong pointing object 1749 65536 (offset 0)
# Ignoring wrong pointing object 1753 65536 (offset 0)
# Ignoring wrong pointing object 1760 65536 (offset 0)
# Ignoring wrong pointing object 1767 65536 (offset 0)
# Ignoring wrong pointing object 1774 65536 (offset 0)
# Ignoring wrong pointing object 1809 65536 (offset 0)
# Ignoring wrong pointing object 1886 65536 (offset 0)
# Ignoring wrong pointing object 1917 65536 (offset 0)
# Ignoring wrong pointing object 1941 65536 (offset 0)
# Ignoring wrong pointing object 1945 65536 (offset 0)
# Ignoring wrong pointing object 1972 65536 (offset 0)
# Ignoring wrong pointing object 2013 65536 (offset 0)
# Ignoring wrong pointing object 2017 65536 (offset 0)
# Ignoring wrong pointing object 2021 65536 (offset 0)
# Ignoring wrong pointing object 2025 65536 (offset 0)
# Ignoring wrong pointing object 2054 65536 (offset 0)
# Ignoring wrong pointing object 2062 65536 (offset 0)
# Ignoring wrong pointing object 2066 65536 (offset 0)
# Ignoring wrong pointing object 2078 65536 (offset 0)
# Ignoring wrong pointing object 2082 65536 (offset 0)
# Ignoring wrong pointing object 2110 65536 (offset 0)
# Ignoring wrong pointing object 2123 65536 (offset 0)
# Ignoring wrong pointing object 2129 65536 (offset 0)
# Ignoring wrong pointing object 2139 65536 (offset 0)
# Ignoring wrong pointing object 2146 65536 (offset 0)
# Ignoring wrong pointing object 2164 65536 (offset 0)
# Ignoring wrong pointing object 2174 65536 (offset 0)
# Ignoring wrong pointing object 2178 65536 (offset 0)
# Ignoring wrong pointing object 2182 65536 (offset 0)
# Ignoring wrong pointing object 2186 65536 (offset 0)
# Ignoring wrong pointing object 2190 65536 (offset 0)
# Ignoring wrong pointing object 2194 65536 (offset 0)
# Ignoring wrong pointing object 2198 65536 (offset 0)
# Ignoring wrong pointing object 2202 65536 (offset 0)
# Ignoring wrong pointing object 2206 65536 (offset 0)
# Ignoring wrong pointing object 2210 65536 (offset 0)
# Ignoring wrong pointing object 2214 65536 (offset 0)
# Ignoring wrong pointing object 2218 65536 (offset 0)
# Ignoring wrong pointing object 2222 65536 (offset 0)
# Ignoring wrong pointing object 2227 65536 (offset 0)
# Ignoring wrong pointing object 2231 65536 (offset 0)
# Ignoring wrong pointing object 2235 65536 (offset 0)
# Ignoring wrong pointing object 2239 65536 (offset 0)
# Ignoring wrong pointing object 2243 65536 (offset 0)
# Ignoring wrong pointing object 2247 65536 (offset 0)
# Ignoring wrong pointing object 2251 65536 (offset 0)
# Ignoring wrong pointing object 2255 65536 (offset 0)
# Ignoring wrong pointing object 2259 65536 (offset 0)
# Ignoring wrong pointing object 2263 65536 (offset 0)
# Ignoring wrong pointing object 2267 65536 (offset 0)
# Ignoring wrong pointing object 2298 65536 (offset 0)
# Ignoring wrong pointing object 2315 65536 (offset 0)
# Ignoring wrong pointing object 2423 65536 (offset 0)
# Ignoring wrong pointing object 2441 65536 (offset 0)
# Ignoring wrong pointing object 2455 65536 (offset 0)
# Ignoring wrong pointing object 2479 65536 (offset 0)
# Ignoring wrong pointing object 2519 65536 (offset 0)
# Ignoring wrong pointing object 2563 65536 (offset 0)
# Ignoring wrong pointing object 2585 65536 (offset 0)
# Ignoring wrong pointing object 2602 65536 (offset 0)
# Ignoring wrong pointing object 2649 65536 (offset 0)
# Ignoring wrong pointing object 2687 65536 (offset 0)
# Ignoring wrong pointing object 2834 65536 (offset 0)
# Ignoring wrong pointing object 2852 65536 (offset 0)
# Ignoring wrong pointing object 3055 65536 (offset 0)
# Ignoring wrong pointing object 3070 65536 (offset 0)
# Ignoring wrong pointing object 3084 65536 (offset 0)
# Ignoring wrong pointing object 3108 65536 (offset 0)
# Ignoring wrong pointing object 3128 65536 (offset 0)
# Ignoring wrong pointing object 3161 65536 (offset 0)
# Ignoring wrong pointing object 3189 65536 (offset 0)
# Ignoring wrong pointing object 3217 65536 (offset 0)
# Ignoring wrong pointing object 3263 65536 (offset 0)
# Ignoring wrong pointing object 3285 65536 (offset 0)
# Ignoring wrong pointing object 3349 65536 (offset 0)
# Ignoring wrong pointing object 3380 65536 (offset 0)
# Ignoring wrong pointing object 3399 65536 (offset 0)
# Ignoring wrong pointing object 3424 65536 (offset 0)
# Ignoring wrong pointing object 3428 65536 (offset 0)
# Ignoring wrong pointing object 3432 65536 (offset 0)
# Ignoring wrong pointing object 3468 65536 (offset 0)
# Ignoring wrong pointing object 3472 65536 (offset 0)
# Ignoring wrong pointing object 3476 65536 (offset 0)
# Ignoring wrong pointing object 3480 65536 (offset 0)
# Ignoring wrong pointing object 3484 65536 (offset 0)
# Ignoring wrong pointing object 3499 65536 (offset 0)
# Ignoring wrong pointing object 46 0 (offset 0)
# Ignoring wrong pointing object 48 0 (offset 0)
# Ignoring wrong pointing object 170 0 (offset 0)
# Ignoring wrong pointing object 27 0 (offset 0)
# Ignoring wrong pointing object 76 0 (offset 0)
# Ignoring wrong pointing object 442 0 (offset 0)
# Ignoring wrong pointing object 444 0 (offset 0)
# Ignoring wrong pointing object 446 0 (offset 0)
# Ignoring wrong pointing object 448 0 (offset 0)
# Ignoring wrong pointing object 625 0 (offset 0)
# Ignoring wrong pointing object 632 0 (offset 0)
# Ignoring wrong pointing object 643 0 (offset 0)
# Ignoring wrong pointing object 696 0 (offset 0)
# Ignoring wrong pointing object 735 0 (offset 0)
# Ignoring wrong pointing object 738 0 (offset 0)
# Ignoring wrong pointing object 747 0 (offset 0)
# Ignoring wrong pointing object 828 0 (offset 0)
# Ignoring wrong pointing object 851 0 (offset 0)
# Ignoring wrong pointing object 34 0 (offset 0)
# Ignoring wrong pointing object 67 0 (offset 0)
# Ignoring wrong pointing object 120 0 (offset 0)
# Ignoring wrong pointing object 129 0 (offset 0)
# Ignoring wrong pointing object 222 0 (offset 0)
# Ignoring wrong pointing object 248 0 (offset 0)
# Multiple definitions in dictionary at byte 0x2cf for key /F24
# Multiple definitions in dictionary at byte 0x2da for key /F24
# Multiple definitions in dictionary at byte 0x74b for key /F31
# Multiple definitions in dictionary at byte 0x60a3 for key /F31
# Multiple definitions in dictionary at byte 0x60ae for key /F24
# Multiple definitions in dictionary at byte 0x60c5 for key /F24
# Multiple definitions in dictionary at byte 0x60dd for key /F24
# Multiple definitions in dictionary at byte 0x60e9 for key /F40
# Multiple definitions in dictionary at byte 0x6de0 for key /F24
# Multiple definitions in dictionary at byte 0x9494 for key /F31
# Multiple definitions in dictionary at byte 0x9e99 for key /F24
# Multiple definitions in dictionary at byte 0x9ec8 for key /F24
# Multiple definitions in dictionary at byte 0xadf6 for key /F40
# Multiple definitions in dictionary at byte 0xae01 for key /F24
# Multiple definitions in dictionary at byte 0xe868 for key /F24
# Multiple definitions in dictionary at byte 0xfce8 for key /F24
# Multiple definitions in dictionary at byte 0x10883 for key /F24
# Multiple definitions in dictionary at byte 0x11649 for key /F31
# Multiple definitions in dictionary at byte 0x12cba for key /F31
# Multiple definitions in dictionary at byte 0x132a0 for key /F31
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 33 0 (offset 0)
# Ignoring wrong pointing object 39 0 (offset 0)
# Ignoring wrong pointing object 30 0 (offset 0)
# Ignoring wrong pointing object 33 0 (offset 0)
# Ignoring wrong pointing object 53 0 (offset 0)
# Ignoring wrong pointing object 201 0 (offset 0)
# Ignoring wrong pointing object 202 0 (offset 0)
# Ignoring wrong pointing object 211 0 (offset 0)
# Ignoring wrong pointing object 212 0 (offset 0)
# Ignoring wrong pointing object 219 0 (offset 0)
# Ignoring wrong pointing object 220 0 (offset 0)
# Ignoring wrong pointing object 227 0 (offset 0)
# Ignoring wrong pointing object 228 0 (offset 0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b7b9e950c32a> in <module>
#       1 loader = PyPDFDirectoryLoader("./pdfs-master")
# ----> 2 docs = loader.load()
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\langchain_community\document_loaders\pdf.py in load(self)
#     262                             logger.warning(e)
#     263                         else:
# --> 264                             raise e
#     265         return docs
#     266
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\langchain_community\document_loaders\pdf.py in load(self)
#     254                     try:
#     255                         loader = PyPDFLoader(str(i), extract_images=self.extract_images)
# --> 256                         sub_docs = loader.load()
#     257                         for doc in sub_docs:
#     258                             doc.metadata["source"] = str(i)
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\langchain_core\document_loaders\base.py in load(self)
#      27     def load(self) -> List[Document]:
#      28         """Load data into Document objects."""
# ---> 29         return list(self.lazy_load())
#      30
#      31     async def aload(self) -> List[Document]:
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\langchain_community\document_loaders\pdf.py in lazy_load(self)
#     191         else:
#     192             blob = Blob.from_path(self.file_path)
# --> 193         yield from self.parser.parse(blob)
#     194
#     195
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\langchain_core\document_loaders\base.py in parse(self, blob)
#     123             List of documents
#     124         """
# --> 125         return list(self.lazy_parse(blob))
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\langchain_community\document_loaders\parsers\pdf.py in lazy_parse(self, blob)
#      94         with blob.as_bytes_io() as pdf_file_obj:
#      95             pdf_reader = pypdf.PdfReader(pdf_file_obj, password=self.password)
# ---> 96             yield from [
#      97                 Document(
#      98                     page_content=page.extract_text()
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\langchain_community\document_loaders\parsers\pdf.py in <listcomp>(.0)
#      94         with blob.as_bytes_io() as pdf_file_obj:
#      95             pdf_reader = pypdf.PdfReader(pdf_file_obj, password=self.password)
# ---> 96             yield from [
#      97                 Document(
#      98                     page_content=page.extract_text()
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\pypdf\_page.py in __iter__(self)
#    2275
#    2276     def __iter__(self) -> Iterator[PageObject]:
# -> 2277         for i in range(len(self)):
#    2278             yield self[i]
#    2279
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\pypdf\_page.py in __len__(self)
#    2206
#    2207     def __len__(self) -> int:
# -> 2208         return self.length_function()
#    2209
#    2210     @overload
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\pypdf\_doc_common.py in get_num_pages(self)
#     351         else:
#     352             if self.flattened_pages is None:
# --> 353                 self._flatten()
#     354             assert self.flattened_pages is not None
#     355             return len(self.flattened_pages)
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\pypdf\_doc_common.py in _flatten(self, pages, inherit, indirect_reference)
#    1120                 if obj:
#    1121                     # damaged file may have invalid child in /Pages
# -> 1122                     self._flatten(obj, inherit, **addt)
#    1123         elif t == "/Page":
#    1124             for attr_in, value in list(inherit.items()):
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\pypdf\_doc_common.py in _flatten(self, pages, inherit, indirect_reference)
#    1120                 if obj:
#    1121                     # damaged file may have invalid child in /Pages
# -> 1122                     self._flatten(obj, inherit, **addt)
#    1123         elif t == "/Page":
#    1124             for attr_in, value in list(inherit.items()):
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\pypdf\_doc_common.py in _flatten(self, pages, inherit, indirect_reference)
#    1120                 if obj:
#    1121                     # damaged file may have invalid child in /Pages
# -> 1122                     self._flatten(obj, inherit, **addt)
#    1123         elif t == "/Page":
#    1124             for attr_in, value in list(inherit.items()):
#
# c:\Users\TUF GAMING\miniconda3\Lib\site-packages\pypdf\_doc_common.py in _flatten(self, pages, inherit, indirect_reference)
#    1101             self.flattened_pages = []
#    1102
# -> 1103         if PA.TYPE in pages:
#    1104             t = cast(str, pages[PA.TYPE])
#    1105         # if pdf has no type, considered as a page if /Kids is missing
#
# TypeError: argument of type 'NullObject' is not iterable

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter= RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=100,
    length_function=len
)   

print("Document splitting a in process")
docs = text_splitter.split_documents(docs)
print("Document splitted")
docs[1]
# Out:
# Document splitting a in process
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3fffc81a8431> in <module>
#       8
#       9 print("Document splitting a in process")
# ---> 10 docs = text_splitter.split_documents(docs)
#      11 print("Document splitted")
#      12 docs[1]
#
# NameError: name 'docs' is not defined
